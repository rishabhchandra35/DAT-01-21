# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('../data/titanic.csv')

# %%
df['Embarked'].value_counts().plot(kind='bar', colors=['blue', 'green', 'red']);
# Out:
# C:\Users\Jonat\Anaconda\lib\site-packages\pandas\plotting\_core.py:194: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"

# %%
# ?df.plot

# %%
plt.style.use('ggplot')

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
stocks2 = pd.read_csv('../data/stocks.csv')

# %%
stocks2.melt(id_vars='Date', value_vars=['AAPL', 'GOOGL', 'FB', 'MSFT', 'AMZN'])
# Out:
#             Date variable        value
# 0     2014-11-05     AAPL   108.860001
# 1     2014-11-06     AAPL   108.699997
# 2     2014-11-07     AAPL   109.010002
# 3     2014-11-10     AAPL   108.830002
# 4     2014-11-11     AAPL   109.699997
# 5     2014-11-12     AAPL   111.250000
# 6     2014-11-13     AAPL   112.820000
# 7     2014-11-14     AAPL   114.180000
# 8     2014-11-17     AAPL   113.989998
# 9     2014-11-18     AAPL   115.470001
# 10    2014-11-19     AAPL   114.669998
# 11    2014-11-20     AAPL   116.309998
# 12    2014-11-21     AAPL   116.470001
# 13    2014-11-24     AAPL   118.629997
# 14    2014-11-25     AAPL   117.599998
# 15    2014-11-26     AAPL   119.000000
# 16    2014-11-28     AAPL   118.930000
# 17    2014-12-01     AAPL   115.070000
# 18    2014-12-02     AAPL   114.629997
# 19    2014-12-03     AAPL   115.930000
# 20    2014-12-04     AAPL   115.489998
# 21    2014-12-05     AAPL   115.000000
# 22    2014-12-08     AAPL   112.400002
# ...

# %%
panel_stocks = stocks2.melt(id_vars='Date', value_vars=['AAPL', 'GOOGL', 'FB', 'MSFT', 'AMZN'])

# %%
panel_stocks.pivot(index='Date', columns='variable', values='value')
# Out:
# variable          AAPL         AMZN          FB        GOOGL        MSFT
# Date
# 2014-11-05  108.860001   296.519989   74.830002   555.950012   47.860001
# 2014-11-06  108.699997   296.640015   75.260002   551.690002   48.700001
# 2014-11-07  109.010002   299.859985   75.599998   551.820007   48.680000
# 2014-11-10  108.830002   305.109985   75.000000   558.229980   48.889999
# 2014-11-11  109.699997   312.010010   74.610001   561.289978   48.869999
# 2014-11-12  111.250000   311.510010   74.720001   558.250000   48.779999
# 2014-11-13  112.820000   316.480011   74.250000   556.440002   49.610001
# 2014-11-14  114.180000   327.820007   74.879997   555.190002   49.580002
# 2014-11-17  113.989998   323.049988   74.239998   546.640015   49.459999
# 2014-11-18  115.470001   324.929993   74.339996   544.510010   48.740002
# 2014-11-19  114.669998   326.540009   73.330002   547.200012   48.220001
# 2014-11-20  116.309998   330.540009   73.599998   543.760010   48.700001
# ...

# %%
import statsmodels.api as sm

# %%
stocks2['AAPL'].diff()
# Out:
# 0            NaN
# 1      -0.160004
# 2       0.310005
# 3      -0.180000
# 4       0.869995
# 5       1.550003
# 6       1.570000
# 7       1.360000
# 8      -0.190002
# 9       1.480003
# 10     -0.800003
# 11      1.640000
# 12      0.160003
# 13      2.159996
# 14     -1.029999
# 15      1.400002
# 16     -0.070000
# 17     -3.860000
# 18     -0.440003
# 19      1.300003
# 20     -0.440002
# 21     -0.489998
# 22     -2.599998
# 23      1.720001
# 24     -2.170006
# 25     -0.329994
# 26     -1.890000
# 27     -1.500000
# 28     -1.480003
# 29      2.660004
#           ...
# 1227    0.990005
# 1228   -1.040008
# 1229    3.350006
# 1230   -1.140000
# 1231   -1.069992
# 1232    5.149994
# 1233    0.619995
# 1234   -5.629989
# 1235    1.860000
# 1236    6.189988
# 1237    0.050003
# 1238   -2.660004
# 1239    2.630005
# 1240    3.059997
# 1241    6.120011
# 1242   -0.340012
# 1243   -0.549988
# 1244   -0.950012
# 1245    0.910004
# 1246    1.130005
# 1247    4.099991
# ...

# %%
sm.graphics.tsa.plot_acf(stocks2['AAPL'], lags=50)

# %%
sm.graphics.tsa.plot_pacf(stocks2['AAPL'].diff()[1:])

# %%
stocks
# Out:
#            Date  Stock        Price
# 0    2014-11-05   AAPL   108.860001
# 1    2014-11-05   AMZN   296.519989
# 2    2014-11-05     FB    74.830002
# 3    2014-11-05   MSFT    47.860001
# 4    2014-11-05  GOOGL   555.950012
# 5    2014-11-06     FB    75.260002
# 6    2014-11-06  GOOGL   551.690002
# 7    2014-11-06   AMZN   296.640015
# 8    2014-11-06   AAPL   108.699997
# 9    2014-11-06   MSFT    48.700001
# 10   2014-11-07   MSFT    48.680000
# 11   2014-11-07   AAPL   109.010002
# 12   2014-11-07   AMZN   299.859985
# 13   2014-11-07  GOOGL   551.820007
# 14   2014-11-07     FB    75.599998
# 15   2014-11-10     FB    75.000000
# 16   2014-11-10   MSFT    48.889999
# 17   2014-11-10   AMZN   305.109985
# 18   2014-11-10   AAPL   108.830002
# 19   2014-11-10  GOOGL   558.229980
# 20   2014-11-11  GOOGL   561.289978
# 21   2014-11-11   AAPL   109.699997
# 22   2014-11-11     FB    74.610001
# 23   2014-11-11   MSFT    48.869999
# 24   2014-11-11   AMZN   312.010010
# ...

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr());

# %%
sns.catplot(x='Pclass', y='Age', kind='box', data=df);
