# %%
import pandas as pd

# %%
stocks = pd.read_csv('../data/stocks.csv')

# %%
# Out:
# Empty DataFrame
# Columns: [Date, variable, value]
# Index: []

# %%
stocks.head()
# Out:
#          Date        AAPL       GOOGL         FB       MSFT        AMZN
# 0  2014-11-05  108.860001  555.950012  74.830002  47.860001  296.519989
# 1  2014-11-06  108.699997  551.690002  75.260002  48.700001  296.640015
# 2  2014-11-07  109.010002  551.820007  75.599998  48.680000  299.859985
# 3  2014-11-10  108.830002  558.229980  75.000000  48.889999  305.109985
# 4  2014-11-11  109.699997  561.289978  74.610001  48.869999  312.010010

# %%
stocks.melt(id_vars='Date', value_vars=['AAPL','GOOGL','FB','MSFT','AMZN'])
# Out:
#             Date variable        value
# 0     2014-11-05     AAPL   108.860001
# 1     2014-11-06     AAPL   108.699997
# 2     2014-11-07     AAPL   109.010002
# 3     2014-11-10     AAPL   108.830002
# 4     2014-11-11     AAPL   109.699997
# ...          ...      ...          ...
# 6280  2019-10-28     AMZN  1777.079956
# 6281  2019-10-29     AMZN  1762.709961
# 6282  2019-10-30     AMZN  1779.989990
# 6283  2019-10-31     AMZN  1776.660034
# 6284  2019-11-01     AMZN  1791.439941
#
# [6285 rows x 3 columns]

# %%
df = stocks.melt(id_vars='Date', value_vars=['AAPL','GOOGL','FB','MSFT','AMZN'])

# %%
df.pivot(index= 'Date', columns='variable', values='value')
# Out:
# variable          AAPL         AMZN          FB        GOOGL        MSFT
# Date
# 2014-11-05  108.860001   296.519989   74.830002   555.950012   47.860001
# 2014-11-06  108.699997   296.640015   75.260002   551.690002   48.700001
# 2014-11-07  109.010002   299.859985   75.599998   551.820007   48.680000
# 2014-11-10  108.830002   305.109985   75.000000   558.229980   48.889999
# 2014-11-11  109.699997   312.010010   74.610001   561.289978   48.869999
# ...                ...          ...         ...          ...         ...
# 2019-10-28  249.050003  1777.079956  189.399994  1288.979980  144.190002
# 2019-10-29  243.289993  1762.709961  189.309998  1260.660034  142.830002
# 2019-10-30  243.259995  1779.989990  188.250000  1260.699951  144.610001
# 2019-10-31  248.759995  1776.660034  191.649994  1258.800049  143.369995
# 2019-11-01  255.820007  1791.439941  193.619995  1272.250000  143.720001
#
# [1257 rows x 5 columns]

# %%
# Grandfather of plotting is matplotlib, similar to how matlab is the father or pandas 
#when you import pandas, you have matplotlib 
#seaborn is a user friendly version of matplotlib

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
df= pd.read_csv('../data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind="bar")

# %%
df['Embarked'].plot(kind='bar')
#this doesn't work because there are no numerical values to plot. its categorical
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-bd3488d90cce> in <module>
# ----> 1 df['Embarked'].plot(kind='bar')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='bar')

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='barh')
#same as above but horizontal

# %%
df['Embarked'].value_counts().plot(kind='pie')

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
df['Embarked'].value_counts().plot(kind='pie'); 
#if you add semicolon, you won't get the messy <matplotlib.axes._subplots.AxesSubplot at 0x114f5ff90> thing

# %%
df['Embarked'].value_counts().plot(kind='pie',colors=['blue','green','red']);

# %%
df['Age'].plot(kind='hist')

# %%
df['Age'].plot(kind='hist',bins=20)

# %%
df.hist(column='Age',by='Embarked')
# you can do this w histograms and boxplots only
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11538f710>,
# ...
#       dtype=object)

# %%
df.boxplot(column='Age',by='Embarked')

# %%
df.hist(column='Age',by='Embarked',layout=(1,3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1156efa50>,
# ...
#       dtype=object)

# %%
df.hist(column='Age',by='Embarked',layout=(1,3), figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1156f6310>,
# ...
#       dtype=object)

# %%
df.hist(column='Age',by='Embarked',layout=(1,3), figsize=(12,4),sharey=True)
# this lets you scale it better,  You can also do sharex
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11527b7d0>,
# ...
#       dtype=object)

# %%
df['Age'].plot(kind='kde')
# smoother version of histogram.  Though histogram shows you value counts and kde shows you % of all values

# %%
df.plot('Age','Fare',kind='scatter')
# scatter plot you don't specify the series

# %% [markdown]
# ### SEABORN

# %%
#seaborn is good for categorical data 
import seaborn as sns

# %%
sns.catplot(x='Pclass', y='Age', data=df)

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='swarm')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='strip')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='box')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='boxen')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='violin')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='point')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='bar')

# %%
sns.catplot(x='Pclass', data=df, kind='count')  # only one variable

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='swarm',hue='Sex')

# %%
sns.catplot(x='Pclass', y='Age', data=df, kind='swarm',col='Sex')

# %%
sns.lmplot(x='Pclass',y='Survived',data = df)
#

# %%
df['Age']= df['Age'].fillna(29)
sns.distplot(df.Age)

# %%
sns.jointplot(x='Age',y='Fare',data=df[df.Sex=='male'])
#hue and col can't be used on histplot types

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,x_vars=['Fare',], y_vars=['Survived'])

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033632 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.067814 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.334974  0.083081  0.018443
# Age             0.033632 -0.067814 -0.334974  1.000000 -0.232978 -0.176486
# SibSp          -0.057527 -0.035322  0.083081 -0.232978  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.176486  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.093706  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.093706
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr())
#visualize the correlation between values
