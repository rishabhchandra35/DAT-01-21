# %% [markdown]
# ### Class Example:  Building A Web Scraper

# %% [markdown]
# This notebook will go over briefly how you build a web-scraper, and relate it to a few different concepts covered so far in this workshop.

# %% [markdown]
# **Important**:  This example is not meant to explain every single line of code that's used, but merely to relate some important concepts discussed in class to a real world example.  It's okay if you don't understand everything that's shown here, just focus on the bigger picture, and turn this notebook into a follow up project after the workshop.

# %% [markdown]
# **Step 1**:  Do the imports

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %% [markdown]
# **Step 2**: Connect to the URL using the requests library.

# %%
url         = 'https://generalassemb.ly/education'

params      = {
                'where'  : 'new-york-city',
                'format' : 'classes-workshops'
              }

r           = requests.get(url, params=params)

# %% [markdown]
# Now, we have the contents of the website saved as a variable 'r'.
#
# We can now grab the entire content of the website as a piece of text.

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<head>\n<script src="https://cdn.cookielaw.org/consent/4f740341-5e77-436b-9272-34eefbc7a4e4.js"></script>\n<script src="//s3.amazonaws.com/static-assets.generalassemb.ly/cookie-consent/current/cookie-consent.js"></script>\n<script>\n  if (!window.cookieConsent) {\n    window.cookieConsent = new CookieConsent()\n    window.cookieConsent.initBrowser()\n  }\n</script>\n\n<script async src=\'//cdn.optimizely.com/js/15543840407.js\'></script>\n\n<title>Web Design, Business, Technology Classes and | General Assembly</title>\n<meta name="description" content="General Assembly hosts business, design, and technology courses, classes, and workshops." />\n<link rel="canonical" href="https://generalassemb.ly/education" />\n<meta property="og:title" content="Web Design, Business, Technology Classes and Immersives" />\n<meta property="og:type" content="website" />\n<meta property="og:url" content="https://generalassemb.ly/education?where=new-york-city&amp;format=classes-workshops" />\n<meta property="og:image" content="https://ga-core-production-herokuapp-com.global.ssl.fastly.net/assets/shared/ga-lockup-91201f0cd75f003713327680fb3975c1.png" />\n<meta name="twitter:cards" content="summary" />\n<meta name="twitter:url" content="https://generalassemb.ly/education?where=new-york-city&amp;format=classes-workshops" />\n<meta name="twitter:title" content="Web Design, Business, Technology Classes and Immersives" />\n<meta name="twitter:description" content="General Assembly hosts business, design, and technology courses, classes, and workshops." />\n<meta name="twitter:image" content="https://ga-core-production-herokuapp-com.global.ssl.fastly.net/assets/shared/ga-lockup-91201f0cd75f003713327680fb3975c1.png" />\n<meta name="twitter:site" content="@ga" />\n<meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="raQmwzsakSnchJdsXZ3m7x6Xz0SMPYalqjGgAdO1bMmuFKCf2kkLuClNNfl3stx/wE/51vMF4xc5FoXbBlqtOw==" />\n<meta content=\'text/html; charset=UTF-8\' http-equiv=\'Content-Type\'>\n<meta content=\'initial-scale=1.0, width=device-width, maximum-scale=1.0\' name=\'viewport\'>\n<meta content=\'IE=Edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"44a7295480","applicationID":"62356589","transactionName":"dg1aRxMMCghUEBlcV0ABVUcIDAhLWAxSXEs=","queueTime":4,"applicationTime":37,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQAPVFJWCRAGVlJXAQQPXw==",licenseKey:"44a7295480",applicationID:"62356589"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(20),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(21),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h ...

# %% [markdown]
# **Our Problem**:  We don't need the vast majority of this information.  Just the list at the bottom of the page that contains the information about the classes.
#
# To turn this into actual data, we need to accomplish two steps:
#
#  - Extract the portion of the string that ONLY contains what we need
#  - Convert this into an actual python list that we can then further manipulate to our desires.
#
# Some of this code we are not going to go over, so make a note to do follow up study on what you don't understand:

# %%
# turn the request text into a web scraping object
doc         = BeautifulSoup(r.text, 'html.parser')
# grab all the script tags, then use slices to get the one that we want
script     = doc.find_all('script')[-2]
# convert the web scraping object into a string
text        = str(script)

# %% [markdown]
# Now let's take a look at our variable text:

# %%
text
# Out:
# '<script>\n  window.EDUCATIONAL_OFFERINGS_JSON = [{"format":"workshop","overview":"Creating a perfect resumé from a recruiter’s lense!","topics":[{"id":9,"name":"Career Development","asset_folder":"career_development"}],"instructors":[{"id":20807,"name":"Daniel Robinson","title":"Career Coach \\u0026 Employer Partnerships, General Assembly"}],"title":"The Resumé Run-Down","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/the-resume-run-down/new-york-city/93407","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/12118/thumb_thumb_Tech_Branding_Networking_You_Hand_Business_Card.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 - 11:30am EST"},{"format":"workshop","overview":"Find out which of your ideas are most viable by learning how to test them quickly and efficiently.","topics":[{"id":1,"name":"Business","asset_folder":"business"}],"instructors":[{"id":17756,"name":"Ryan Cooley","title":"Head of Product, Human Ventures"}],"title":"Product Management Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/product-management-bootcamp/new-york-city/83894","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/1327/thumb_Bootcamp_ProductManagement.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop-series","overview":"Learn the fundamentals of front-end and back-end programming, plus try your hand at writing some code of your own.\\r\\n","topics":[{"id":6,"name":"Coding","asset_folder":"coding"}],"instructors":[{"id":2791,"name":"Michael Glumac","title":"Front-End Engineering Lead, Imagebrief"}],"title":"Programming for Non-Programmers Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/programming-for-non-programmers-bootcamp/new-york-city/84800","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/1188/thumb_Bootcamp_HTMLCSSWebDesign.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":"2 Sessions","date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop","overview":"Learn how to use your Google Analytics to get real insights into your website’s visitors, their behavior and any patterns and trends.","topics":[{"id":14,"name":"Marketing","asset_folder":"marketing"},{"id":8,"name":"Data","asset_folder":"data"}],"instructors":[{"id":7129,"name":"Kassie Phillips","title":"Creative Strategist and Digital Marketing Consultant"}],"title":"Google Analytics Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/google-analytics-bootcamp/new-york-city/83886","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/3033/thumb_Marketing_Paid_Google_Analytic_arrow_search_desktop.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop","overview":"In this introductory class, learn how to build an email marketing strategy that grows your business by acquiring and retaining customers.\\r\\n","topics":[{"id":14,"name":"Marketing","asset_folder":"marketing"}],"instructors":[{"id":13206,"name":"Sharon Lee Thony","title":"Digital Marketing Executive, Founder \\u0026 Principal of SLT Consulting, Sharon Lee Thony Consulting"}],"title":"Email Marketing for Entrepreneurs and Startups","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/email-marketing-for-entrepreneurs-and-startu ...

# %% [markdown]
# This is still closer to what we want, but we need to whittle it down to the actual list that we need, and nothing else.

# %%
# get the index position of where our string ends
end         = text.index('window.TOPICS_JSON')
# these two lines create slices reduce the string to the exact positions of the list 
text        = text[:end]
text        = text[47:-4]

# %% [markdown]
# Now let's go ahead and take a look at our text variable:

# %%
text
# Out:
# '[{"format":"workshop","overview":"Creating a perfect resumé from a recruiter’s lense!","topics":[{"id":9,"name":"Career Development","asset_folder":"career_development"}],"instructors":[{"id":20807,"name":"Daniel Robinson","title":"Career Coach \\u0026 Employer Partnerships, General Assembly"}],"title":"The Resumé Run-Down","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/the-resume-run-down/new-york-city/93407","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/12118/thumb_thumb_Tech_Branding_Networking_You_Hand_Business_Card.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 - 11:30am EST"},{"format":"workshop","overview":"Find out which of your ideas are most viable by learning how to test them quickly and efficiently.","topics":[{"id":1,"name":"Business","asset_folder":"business"}],"instructors":[{"id":17756,"name":"Ryan Cooley","title":"Head of Product, Human Ventures"}],"title":"Product Management Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/product-management-bootcamp/new-york-city/83894","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/1327/thumb_Bootcamp_ProductManagement.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop-series","overview":"Learn the fundamentals of front-end and back-end programming, plus try your hand at writing some code of your own.\\r\\n","topics":[{"id":6,"name":"Coding","asset_folder":"coding"}],"instructors":[{"id":2791,"name":"Michael Glumac","title":"Front-End Engineering Lead, Imagebrief"}],"title":"Programming for Non-Programmers Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/programming-for-non-programmers-bootcamp/new-york-city/84800","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/1188/thumb_Bootcamp_HTMLCSSWebDesign.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":"2 Sessions","date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop","overview":"Learn how to use your Google Analytics to get real insights into your website’s visitors, their behavior and any patterns and trends.","topics":[{"id":14,"name":"Marketing","asset_folder":"marketing"},{"id":8,"name":"Data","asset_folder":"data"}],"instructors":[{"id":7129,"name":"Kassie Phillips","title":"Creative Strategist and Digital Marketing Consultant"}],"title":"Google Analytics Bootcamp","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/google-analytics-bootcamp/new-york-city/83886","image_url":"https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/3033/thumb_Marketing_Paid_Google_Analytic_arrow_search_desktop.jpg","duration_description":null,"next_info_session":null,"number_of_sessions":null,"date_num":"14","date_description":"Sat, 14 December","time_description":"10:00 -  5:00pm EST"},{"format":"workshop","overview":"In this introductory class, learn how to build an email marketing strategy that grows your business by acquiring and retaining customers.\\r\\n","topics":[{"id":14,"name":"Marketing","asset_folder":"marketing"}],"instructors":[{"id":13206,"name":"Sharon Lee Thony","title":"Digital Marketing Executive, Founder \\u0026 Principal of SLT Consulting, Sharon Lee Thony Consulting"}],"title":"Email Marketing for Entrepreneurs and Startups","starts":"2019-12-14T15:00:00.000Z","length_in_weeks":null,"url":"http://generalassemb.ly/education/email-marketing-for-entrepreneurs-and-startups/new-york-city/84082","image_url":"https://ga- ...

# %% [markdown]
# This is a list, serialized into a string, that has to be turned back into a list.  So we'll use the JSON library to accomplish this with one line of code.

# %%
data = json.loads(text)
data[5]
# Out:
# {'format': 'workshop',
#  'overview': 'In this introductory class, learn how to build an email marketing strategy that grows your business by acquiring and retaining customers.\r\n',
#  'topics': [{'id': 14, 'name': 'Marketing', 'asset_folder': 'marketing'}],
#  'instructors': [{'id': 13206,
#    'name': 'Sharon Lee Thony',
#    'title': 'Digital Marketing Executive, Founder & Principal of SLT Consulting, Sharon Lee Thony Consulting'}],
#  'title': 'Email Marketing for Entrepreneurs and Startups',
#  'starts': '2019-12-14T15:00:00.000Z',
#  'length_in_weeks': None,
#  'url': 'http://generalassemb.ly/education/email-marketing-for-entrepreneurs-and-startups/new-york-city/84081',
#  'image_url': 'https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/10294/thumb_Marketing_Email_Communication_Envelope_Data_Send_Chart_Open_Card.jpg',
#  'duration_description': None,
#  'next_info_session': None,
#  'number_of_sessions': None,
#  'date_num': '14',
#  'date_description': 'Sat, 14 December',
#  'time_description': '10:00 -  1:00pm EST'}

# %% [markdown]
# And now if we take a look at this, we can this is a normal list, that can be manipulated in every way we've discussed so far today.

# %%
data[0]
# Out:
# {'format': 'workshop',
#  'overview': 'Learn to communicate with databases by learning the language of choice, Structured Query Language (SQL).\r\n',
#  'topics': [{'id': 8, 'name': 'Data', 'asset_folder': 'data'}],
#  'instructors': [{'id': 5455,
#    'name': 'Nigel Caldon',
#    'title': 'Co-Founder, BALLSTAR'}],
#  'title': 'SQL Bootcamp: Learning the Language',
#  'starts': '2019-10-31T14:00:00.000Z',
#  'length_in_weeks': None,
#  'url': 'http://generalassemb.ly/education/sql-bootcamp-learning-the-language/new-york-city/83835',
#  'image_url': 'https://ga-core.s3.amazonaws.com/production/uploads/program/default_image/7867/thumb_Data_Excel_SQL_Analysis_Can_QA_Number_Can_Base_Database.jpg',
#  'duration_description': None,
#  'next_info_session': None,
#  'number_of_sessions': None,
#  'date_num': '31',
#  'date_description': 'Thu, 31 October',
#  'time_description': '10:00 -  5:00pm EDT'}

# %% [markdown]
# And finally, let's do some additional processing to see how we can go ahead and turn this into a dataframe.
#
# **Key Note**:  We are not going to go over these details in class!

# %%
# unpack the information from the instructors dictionary
instructors = [x['instructors'][0]['name'] if x['instructors'] else None for x in data]
# unpack the infomation from the topics dictionary
topics      = [x['topics'][0]['name'] for x in data]
# unpack the information from the date dictionary
date        = [x['starts'] for x in data]

# turn the original list into a datafram
df          = pd.DataFrame(data)

# make new columns from the variables instructors, topics, date
df['Instructor']   = pd.Series(instructors)
df['Topic']        = pd.Series(topics)
df['date']         = pd.to_datetime(date)
df['date']         = df['date'].dt.date
# drop unnecessary column
df                 = df.drop(['url', 'topics', 'instructors', 'image_url', 'next_info_session', 'starts', 'date_description', 'number_of_sessions', 'date_num', 'duration_description'], axis=1)

# %% [markdown]
# And now if we run this, we'll see that this is a very tidy, manageable variable that can be used easily.

# %%
df.head(10)
# Out:
#             format  length_in_weeks  \
# 0         workshop              NaN
# 1         workshop              NaN
# 2  workshop-series              NaN
# 3         workshop              NaN
# 4         workshop              NaN
# 5         workshop              NaN
# 6  workshop-series              NaN
# 7         workshop              NaN
# 8         workshop              NaN
# 9  workshop-series              NaN
#
#                                             overview     time_description  \
# 0  Creating a perfect resumé from a recruiter’s l...  10:00 - 11:30am EST
# 1  Find out which of your ideas are most viable b...  10:00 -  5:00pm EST
# 2  Learn the fundamentals of front-end and back-e...  10:00 -  5:00pm EST
# 3  Learn how to use your Google Analytics to get ...  10:00 -  5:00pm EST
# 4  In this introductory class, learn how to build...  10:00 -  1:00pm EST
# 5  In this introductory class, learn how to build...  10:00 -  1:00pm EST
# 6  Build and Evaluate Machine Learning Models Wit...  10:00 -  5:00pm EST
# 7  Get in the design mindset, learn the principle...  10:00 -  5:00pm EST
# 8  Go from concept to prototype with Adobe XD, th...  10:00 -  5:00pm EST
# 9  User experiences are evolving - fast. Learn ho...  10:00 -  5:00pm EST
#
#                                             title        Instructor  \
# 0                             The Resumé Run-Down   Daniel Robinson
# 1                     Product Management Bootcamp       Ryan Cooley
# 2        Programming for Non-Programmers Bootcamp    Michael Glumac
# 3                       Google Analytics Bootcamp   Kassie Phillips
# 4  Email Marketing for Entrepreneurs and Startups  Sharon Lee Thony
# 5  Email Marketing for Entrepreneurs and Startups  Sharon Lee Thony
# 6     Python and Machine Learning Bootcamp Series  Jonathan Bechtel
# 7                User Experience Journey Workshop    Tyler Hartrich
# 8                               Adobe XD Bootcamp      Ivan Freaner
# 9                  2-Day User Experience Bootcamp      Kyra Peralte
#
#                 Topic        date
# 0  Career Development  2019-12-14
# 1            Business  2019-12-14
# 2              Coding  2019-12-14
# 3           Marketing  2019-12-14
# 4           Marketing  2019-12-14
# 5           Marketing  2019-12-14
# 6                Data  2019-12-14
# 7              Design  2019-12-14
# 8              Design  2019-12-14
# 9              Design  2019-12-14
